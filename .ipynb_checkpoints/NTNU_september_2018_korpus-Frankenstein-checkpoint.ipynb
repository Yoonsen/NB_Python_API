# %% [markdown]
# # Undersøk korpus med metadata
#
# Notebook for å undersøke korpus med metadata

# %%
import nbtext as nb
from nbtext import Corpus
# %matplotlib inline

# %% [markdown]
# <h3> <span style="color:gray;font-family:'Comic Sans MS';">
# Hva som gjøres
# </span></h3><br>
# <div style="font-family:'Palatino Linotype';font-size:1.2em">
# <p>Her bygges korpuset med et implisitt sammenligningskorpus, eller referansekorpus. Målkorpuset er begrenset til periode (*period*) og de andre parametrene som forfatter (*author*), Dewey (*ddk*) og emneord (*subject*). Referansekorpuset er et vilkårlig utvalg av tekster fra samme periode.</p>
#
# </span></h3>
# </div>

# %%
objekt = Corpus(
    period=(1950, 2010),
    title='%',
    subject='krig',
    ddk='%',
    reference=50,
    max_books=50)

# %% [markdown]
# ## Undersøk forskjeller
#
# Dataene viser forskjellem mellom målkorpus og referanse. Se på differansen med kommandoen *difference* som tar et sett parametre. De viktigste for analysen er *freq_exp* som vekter frekvensen til ordene i målkorpuset, og *doc_exp* som vekter dokumentfrekvensen i målkorpuset.
#
# Settes verdien for *top* lik null får du hele korpuset.

# %%
objekt.difference(top=10, aslist=False, freq_exp=1.1, doc_exp=1.5)
# Out:
#                diff
# krig       0.028206
# krigen     0.026703
# soldater   0.023861
# fred       0.023027
# hun        0.022360
# soldatene  0.021721
# militære   0.021165
# lille      0.020970
# Jeg        0.020896
# soldat     0.020778

# %%
objekt.difference(top=150)
# Out:
# krig, soldatene, soldater, fred, krigen, soldat, militære, nu, blev, FN, fly, havde, russiske, våpen, landsbyen, såret, sivile, saa, lille, Afghanistan, skyte, mig, Sovjetunionen, dø, von, tysk, efter, forsvare, hæren, tyskerne, militær, FNs, Krigen, styrker, sårede, Soldatene, 1941, frykt, krigens, Hitler, hun, Johansen, nuclear, president, tyske, sig, kriger, roper, kunde, hvite, New, islam, fronten, Død, soldaten, Moskva, reist, freden, drepte, amerikanske, russisk, Alba, Eriksen, sittende, fortalte, snakke, onkel, verdenskrig, hånden, ff, paa, israelske, forsvar, bordet, husene, europeiske, morgen, nærmest, Adam, ferd, dig, till, bror, musikk, drepe, forsøkte, forlate, Krig, uro, hente, tenkt, 1939, Fienden, nikker, bomber, hat, hodet, och, fiender, makten, forlatt, Spurveliten, amerikansk, allikevel, sier, moralsk, stanset, rom, Jørgen, menneskene, gulvet, Israel, herr, kampene, fredelig, tog, gatene, ud, ventet, Erik, skriver, fullstendig, bombe, dollar, politisk, Deres, muslimske, sovjetiske, War, gråt, kaptein, bussen, lyder, mod, falt, fienden, hevdet, vilde, af, Bosnia, ammunisjon, Libanon, biler, skulde, kalde, islamske, muslimer, Hun, rullet, Knudsen

# %% [markdown]
# <h3> <span style="color:gray;font-family:'Arial';">
# Metadata for objektet
# </span></h3><br><div style="font-family:'Palatino Linotype';font-size:1.2em">
# <p>Objektet bærer med seg informasjon om hva det består av. Bruk *objekt.summary()* for å inspisere</p>
#
# </span></h3>
# </div>

# %%
objekt.summary()
# Out:
# {'parameters': {'author': '%',
#   'ddk': '%',
#   'limit': 50,
#   'next': 60,
#   'reference': 50,
#   'subject': 'krig',
#   'title': '%',
#   'year': 1950},
#  'reference urn': [2014032408157,
#   2011102608073,
#   2012092608145,
#   2014070907006,
#   2014100108152,
#   2007031501073,
#   2016042108122,
#   2011092306085,
#   2011102805100,
#   2011072108072],
#  'target_urn': [2014022808362,
#   2011032208128,
#   2008070400048,
#   2012102306019,
#   2007111304069,
#   2014110607575,
#   2012121007095,
#   2015072408083,
#   2011050508008,
#   2013010705092]}

# %% [markdown]
# ### Søk etter sett av ord i clustret
#
# Finn verdien for ord i clusteret med objekt.check_words('o1 o2 o3 ... oN') med opsjonell spesifikasjon av eksponent. Bare list ordene opp med mellomrom, ord som ikke er i clusteret vil heller ikke vises. Alle andre vises med assosiasjonsverdien og sorteres var høy til lav. Tittel på kolonnen gir en påminnelse om ordet listen er kollokert fra.

# %%
objekt.search_words( 'sår krig . , gevær våpen generaler soldater blod fattigdom nød')
# Out:
#                diff
# krig       0.573108
# soldater   0.542003
# våpen      0.472718
# gevær      0.333840
# nød        0.306214
# fattigdom  0.282014
# ,          0.260247
# .          0.247957
# blod       0.227647
# sår        0.142619

# %% [markdown]
# ## Dataene kan lagres for å hentes frem igjen. Nyttig for å dele data eller for å gjøre dem tilgjengelig for andre analyseredskaper
#
#
# Spesifiser et filnavn, eller la det stå åpent. I så fall bygges filnavnet fra ordet og perioden. Filen lagres i samme mappe som notebooken.

# %%
objekt.save('korpus_test.json')
# Out:
# True

# %% [markdown]
# Last inn det lagrede korpuset og underøk det på samme måte som for ferskbyggede. Bruk *nytt_objekt = Corpus(filename='filavn')*, bytt gjerne ut *nytt_objekt* med et mer deskriptivt navn.

# %%
nytt_objekt = Corpus(filename='korpus_test.json')

# %% [markdown]
# Sjekk at *nytt_objekt* gjør det samme som det opprinnelige korpuset.

# %%
nytt_objekt.difference()
# Out:
# krig, soldatene, soldater, fred, krigen, soldat, militære, nu, blev, FN, fly, havde, russiske, våpen, landsbyen, såret, sivile, saa, lille, Afghanistan, skyte, mig, Sovjetunionen, dø, von, tysk, efter, forsvare, hæren, tyskerne, militær, FNs, Krigen, styrker, sårede, Soldatene, 1941, frykt, krigens, Hitler, hun, Johansen, nuclear, president, tyske, sig, kriger, roper, kunde, hvite, New, islam, fronten, Død, soldaten, Moskva, reist, freden, drepte, amerikanske, russisk, Alba, Eriksen, sittende, fortalte, snakke, onkel, verdenskrig, hånden, ff, paa, israelske, forsvar, bordet, husene, europeiske, morgen, nærmest, Adam, ferd, dig, till, bror, musikk, drepe, forsøkte, forlate, Krig, uro, hente, tenkt, 1939, Fienden, nikker, bomber, hat, hodet, och, fiender, makten, forlatt, Spurveliten, amerikansk, allikevel, sier, moralsk, stanset, rom, Jørgen, menneskene, gulvet, Israel, herr, kampene, fredelig, tog, gatene, ud, ventet, Erik, skriver, fullstendig, bombe, dollar, politisk, Deres, muslimske, sovjetiske, War, gråt, kaptein, bussen, lyder, mod, falt, fienden, hevdet, vilde, af, Bosnia, ammunisjon, Libanon, biler, skulde, kalde, islamske, muslimer, Hun, rullet, Knudsen, flyktningene, leir, FRED, russerne, Jens, Bård, amerikanerne, Saddam, truffet, øyne, Allah, skjebne, Jeg, myndighetene, bygningen, Bagdad, slåss, havnet, Alt, seier, lurte, Vesten, forbi, biological, arabiske, skritt, palestinske, flyktet, Trygve, ben, skjøt, runde, engang, Ibid, halvt, drept, Anna, Barna, Paa, skriker, helvete, ordre, militært, vinduet, Quisling, Heinrich, kjemper, arrestert, Mand, forlot

# %%
nb.cloud(nytt_objekt.difference(aslist=False))
